# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
lr = 1E-6
lr_hist = []
lr_hist.append(lr)
for i in range(100):
    lr = lr * 1.1
    lr_hist.append(lr)

plt.yscale('log')
plt.plot(lr_hist)
