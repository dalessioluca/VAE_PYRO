# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
lr = 1E-4
lr_hist = []
lr_hist.append(lr)
for i in range(13):
    lr = lr * 1.5
    lr_hist.append(lr)

plt.yscale('log')
plt.plot(lr_hist)
